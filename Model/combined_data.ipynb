# %%
import pandas as pd
import csv

# %%
df_metrics = pd.read_csv('C:/Users/PC/Desktop/mitacs/Projet/ansible/playbooks/Model/metrics.csv')
df_smells = pd.read_csv('C:/Users/PC/Desktop/mitacs/Projet/ansible/playbooks/Model/sorted_manual.csv')

# %%
df_smells
# Out:
#                                           Playbook Path Play Name  \
# 0     C:\Users\PC\Desktop\mitacs\Projet\ansible\play...       NaN
# 1                                                   NaN       NaN
# 2                                                   NaN       NaN
# 3                                                   NaN       NaN
# 4                                                   NaN       NaN
# ...                                                 ...       ...
# 2282  C:\Users\PC\Desktop\mitacs\Projet\ansible\play...       NaN
# 2283                                                NaN       NaN
# 2284  C:\Users\PC\Desktop\mitacs\Projet\ansible\play...       NaN
# 2285                                                NaN       NaN
# 2286                                                NaN       NaN
#
#                                               Task Name duplicated code  \
# 0                                                   NaN               0
# ...

# %%
df_smells = df_smells.drop(['Playbook Path', 'Play Name', 'Task Name', 'Filename', 'Full_Path_and_Filename', 'GroupID'], axis=1)

# %%
df_smells
# Out:
#      duplicated code complex playbook high playbook coupling Large Playbook  \
# 0                  0                0                      0              0
# 1                  #                #                      #              #
# 2                  #                #                      #              #
# 3                  #                #                      #              #
# 4                  #                #                      #              #
# ...              ...              ...                    ...            ...
# 2282               0                0                      0              0
# 2283               #                #                      #              #
# 2284               0                0                      0              0
# 2285               #                #                      #              #
# 2286               #                #                      #              #
#
# ...

# %%
df_combined = pd.concat([df_metrics, df_smells], axis=1)

# %%
df_combined
# Out:
#                                           Playbook Name Play Name  \
# 0     C:\Users\PC\Desktop\mitacs\Projet\ansible\play...       NaN
# 1                                                   NaN       NaN
# 2                                                   NaN       NaN
# 3                                                   NaN       NaN
# 4                                                   NaN       NaN
# ...                                                 ...       ...
# 2282  C:\Users\PC\Desktop\mitacs\Projet\ansible\play...       NaN
# 2283                                                NaN       NaN
# 2284  C:\Users\PC\Desktop\mitacs\Projet\ansible\play...       NaN
# 2285                                                NaN       NaN
# 2286                                                NaN       NaN
#
#                                               Task Name  LOC_playbook  \
# 0                                                   NaN          22.0
# ...

# %%
# Sauvegarder le DataFrame dans un fichier CSV
df_combined.to_csv('C:/Users/PC/Desktop/mitacs/Projet/ansible/playbooks/Model/df_combined.csv', index=False)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import csv
import yaml
import seaborn as sns

# %%
# Read the CSV file
df = pd.read_csv('metrics.csv', encoding='latin-1')

# Read the CSV file
df1 = pd.read_csv('metrics_playbooks_with_plays.csv', encoding='latin-1')
df2 = pd.read_csv('score_co_struct.csv', encoding='latin-1')

# %%
df
# Out:
#                                                     File  Lines of Code  \
# 0      C:/Users/PC/Desktop/mitacs/Projet/ansible/play...             14
# 1      C:/Users/PC/Desktop/mitacs/Projet/ansible/play...             17
# 2      C:/Users/PC/Desktop/mitacs/Projet/ansible/play...             92
# 3      C:/Users/PC/Desktop/mitacs/Projet/ansible/play...             15
# 4      C:/Users/PC/Desktop/mitacs/Projet/ansible/play...             31
# ...                                                  ...            ...
# 21622  C:/Users/PC/Desktop/mitacs/Projet/ansible/play...             23
# 21623  C:/Users/PC/Desktop/mitacs/Projet/ansible/play...              5
# 21624  C:/Users/PC/Desktop/mitacs/Projet/ansible/play...            122
# 21625  C:/Users/PC/Desktop/mitacs/Projet/ansible/play...            143
# 21626  C:/Users/PC/Desktop/mitacs/Projet/ansible/play...             10
#
#        Num Plays  Avg Play Size  Num Tasks  Avg Task Size
# ...

# %%
max_value_nloc = df["Lines of Code"].max()
print(max_value_nloc)
# Out:
# 6341

# %%
mean_value_nloc = df["Lines of Code"].mean()
print(mean_value_nloc)
# Out:
# 47.2392379895501

# %%
max_value_nbplays = df1["Num Plays"].max()
print(max_value_nbplays)
# Out:
# 33

# %%
mean_value_nbplays = df["Num Plays"].mean()
print(mean_value_nbplays)
# Out:
# 0.12683220049012808

# %%
max_value_nbtasks = df["Num Tasks"].max()
print(max_value_nbtasks)
# Out:
# 496

# %%
mean_value_nbtasks = df["Num Tasks"].mean()
print(mean_value_nbtasks)
# Out:
# 5.617145235122763

# %%
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a box plot
plt.figure(figsize=(10, 6))
plt.boxplot(df['Lines of Code'])

# Get the statistical values
data = df['Lines of Code']
min_val = np.min(data)
max_val = np.max(data)
mean_val = np.mean(data)
q1 = np.percentile(data, 25)
median_val = np.percentile(data, 50)
q3 = np.percentile(data, 75)

# Highlight the statistical values

plt.axhline(y=min_val, color='red', linestyle='--', label='Min')
plt.axhline(y=max_val, color='blue', linestyle='--', label='Max')
plt.axhline(y=mean_val, color='green', linestyle='--', label='Mean')
plt.axhline(y=q1, color='orange', linestyle='--', label='Q1')
plt.axhline(y=median_val, color='purple', linestyle='--', label='Median')
plt.axhline(y=q3, color='black', linestyle='--', label='Q3')

# Set the x-axis labels
xtick_labels = ['Lines of Code']
plt.xticks(range(1, len(xtick_labels) + 1), xtick_labels)

# Set the y-axis limits
plt.ylim(0, 200)

# Set the plot title and axis labels
plt.title('Lines of Code')
plt.xlabel('Metrics')
plt.ylabel('Lines of Code')

# Add a legend
plt.legend()

# Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a box plot
plt.figure(figsize=(10, 6))
plt.boxplot(df1['Num Plays'])

# Get the statistical values
data = df1['Num Plays']
min_val = np.min(data)
max_val = np.max(data)
mean_val = np.mean(data)
q1 = np.percentile(data, 25)
median_val = np.percentile(data, 50)
q3 = np.percentile(data, 75)

# Highlight the statistical values
highlight_color = 'red'
plt.axhline(y=min_val, color='red', linestyle='--', label='Min')
plt.axhline(y=max_val, color='blue', linestyle='--', label='Max')
plt.axhline(y=mean_val, color='green', linestyle='--', label='Mean')
plt.axhline(y=q1, color='orange', linestyle='--', label='Q1')
plt.axhline(y=median_val, color='purple', linestyle='--', label='Median')
plt.axhline(y=q3, color='black', linestyle='--', label='Q3')

# Set the x-axis labels
xtick_labels = ['Num Plays']
plt.xticks(range(1, len(xtick_labels) + 1), xtick_labels)

# Set the y-axis limits
plt.ylim(0, 5)

# Set the plot title and axis labels
plt.title('Num Plays')
plt.xlabel('Metrics')
plt.ylabel('Num Plays')

# Add a legend
plt.legend()

# Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a box plot
plt.figure(figsize=(10, 6))
plt.boxplot(df1['Avg Play Size'])

# Get the statistical values
data = df1['Avg Play Size']
min_val = np.min(data)
max_val = np.max(data)
mean_val = np.mean(data)
q1 = np.percentile(data, 25)
median_val = np.percentile(data, 50)
q3 = np.percentile(data, 75)

# Highlight the statistical values
highlight_color = 'red'
plt.axhline(y=min_val, color='red', linestyle='--', label='Min')
plt.axhline(y=max_val, color='blue', linestyle='--', label='Max')
plt.axhline(y=mean_val, color='green', linestyle='--', label='Mean')
plt.axhline(y=q1, color='orange', linestyle='--', label='Q1')
plt.axhline(y=median_val, color='purple', linestyle='--', label='Median')
plt.axhline(y=q3, color='black', linestyle='--', label='Q3')

# Set the x-axis labels
xtick_labels = ['Avg Play Size']
plt.xticks(range(1, len(xtick_labels) + 1), xtick_labels)

# Set the y-axis limits
plt.ylim(0, 60)

# Set the plot title and axis labels
plt.title('Avg Play Size')
plt.xlabel('Metrics')
plt.ylabel('Avg Play Size')

# Add a legend
plt.legend()

# Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a box plot
plt.figure(figsize=(10, 6))
plt.boxplot(df['Num Vars'])

# Get the statistical values
data = df['Num Vars']
min_val = np.min(data)
max_val = np.max(data)
mean_val = np.mean(data)
q1 = np.percentile(data, 25)
median_val = np.percentile(data, 50)
q3 = np.percentile(data, 75)

# Highlight the statistical values
highlight_color = 'red'
plt.axhline(y=min_val, color='red', linestyle='--', label='Min')
plt.axhline(y=max_val, color='blue', linestyle='--', label='Max')
plt.axhline(y=mean_val, color='green', linestyle='--', label='Mean')
plt.axhline(y=q1, color='orange', linestyle='--', label='Q1')
plt.axhline(y=median_val, color='purple', linestyle='--', label='Median')
plt.axhline(y=q3, color='black', linestyle='--', label='Q3')

# Set the x-axis labels
xtick_labels = ['Num Vars']
plt.xticks(range(1, len(xtick_labels) + 1), xtick_labels)

# Set the y-axis limits
plt.ylim(0, 20)

# Set the plot title and axis labels
plt.title('Num Vars')
plt.xlabel('Metrics')
plt.ylabel('Num Vars')

# Add a legend
plt.legend()

# Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a box plot
plt.figure(figsize=(10, 6))
plt.boxplot(df['Num Tasks'])

# Get the statistical values
data = df['Num Tasks']
min_val = np.min(data)
max_val = np.max(data)
mean_val = np.mean(data)
q1 = np.percentile(data, 25)
median_val = np.percentile(data, 50)
q3 = np.percentile(data, 75)

# Highlight the statistical values
highlight_color = 'red'
plt.axhline(y=min_val, color='red', linestyle='--', label='Min')
plt.axhline(y=max_val, color='blue', linestyle='--', label='Max')
plt.axhline(y=mean_val, color='green', linestyle='--', label='Mean')
plt.axhline(y=q1, color='orange', linestyle='--', label='Q1')
plt.axhline(y=median_val, color='purple', linestyle='--', label='Median')
plt.axhline(y=q3, color='black', linestyle='--', label='Q3')

# Set the x-axis labels
xtick_labels = ['Num Tasks']
plt.xticks(range(1, len(xtick_labels) + 1), xtick_labels)

# Set the y-axis limits
plt.ylim(0, 20)

# Set the plot title and axis labels
plt.title('Num Tasks')
plt.xlabel('Metrics')
plt.ylabel('Num Tasks')

# Add a legend
plt.legend()

# Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a box plot
plt.figure(figsize=(10, 6))
plt.boxplot(df['Avg Task Size'])

# Get the statistical values
data = df['Avg Task Size']
min_val = np.min(data)
max_val = np.max(data)
mean_val = np.mean(data)
q1 = np.percentile(data, 25)
median_val = np.percentile(data, 50)
q3 = np.percentile(data, 75)

# Highlight the statistical values
highlight_color = 'red'
plt.axhline(y=min_val, color='red', linestyle='--', label='Min')
plt.axhline(y=max_val, color='blue', linestyle='--', label='Max')
plt.axhline(y=mean_val, color='green', linestyle='--', label='Mean')
plt.axhline(y=q1, color='orange', linestyle='--', label='Q1')
plt.axhline(y=median_val, color='purple', linestyle='--', label='Median')
plt.axhline(y=q3, color='black', linestyle='--', label='Q3')

# Set the x-axis labels
xtick_labels = ['Avg Task Size']
plt.xticks(range(1, len(xtick_labels) + 1), xtick_labels)

# Set the y-axis limits
plt.ylim(0, 30)

# Set the plot title and axis labels
plt.title('Avg Task Size')
plt.xlabel('Metrics')
plt.ylabel('Avg Task Size')

# Add a legend
plt.legend()

# Display the plot
plt.tight_layout()
plt.show()

# %%
df1
# Out:
#                                                    File  Lines of Code  \
# 0     C:/Users/PC/Desktop/mitacs/Projet/ansible/play...             17
# 1     C:/Users/PC/Desktop/mitacs/Projet/ansible/play...             92
# 2     C:/Users/PC/Desktop/mitacs/Projet/ansible/play...             15
# 3     C:/Users/PC/Desktop/mitacs/Projet/ansible/play...             31
# 4     C:/Users/PC/Desktop/mitacs/Projet/ansible/play...             26
# ...                                                 ...            ...
# 1811  C:/Users/PC/Desktop/mitacs/Projet/ansible/play...             15
# 1812  C:/Users/PC/Desktop/mitacs/Projet/ansible/play...              9
# 1813  C:/Users/PC/Desktop/mitacs/Projet/ansible/play...              9
# 1814  C:/Users/PC/Desktop/mitacs/Projet/ansible/play...             12
# 1815  C:/Users/PC/Desktop/mitacs/Projet/ansible/play...             12
#
#       Num Plays  Avg Play Size  Num Tasks  Avg Task Size
# 0             3              5          2              5
# ...

# %%
sns.boxplot(data=df2)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a box plot
plt.figure(figsize=(10, 6))
plt.boxplot(df2['Strut Cohesion Inter Plays'])

# Get the statistical values
data = df2['Strut Cohesion Inter Plays']
min_val = np.min(data)
max_val = np.max(data)
mean_val = np.mean(data)
q1 = np.percentile(data, 25)
median_val = np.percentile(data, 50)
q3 = np.percentile(data, 75)

# Highlight the statistical values
highlight_color = 'red'
plt.axhline(y=min_val, color='red', linestyle='--', label='Min')
plt.axhline(y=max_val, color='blue', linestyle='--', label='Max')
plt.axhline(y=mean_val, color='green', linestyle='--', label='Mean')
plt.axhline(y=q1, color='orange', linestyle='--', label='Q1')
plt.axhline(y=median_val, color='purple', linestyle='--', label='Median')
plt.axhline(y=q3, color='black', linestyle='--', label='Q3')

# Set the x-axis labels
xtick_labels = ['Strut Cohesion Inter Plays']
plt.xticks(range(1, len(xtick_labels) + 1), xtick_labels)

# Set the y-axis limits
plt.ylim(0, 1)

# Set the plot title and axis labels
plt.title('Strut Cohesion Inter Plays')
plt.xlabel('Metrics')
plt.ylabel('Strut Cohesion Inter Plays')

# Add a legend
plt.legend()

# Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a box plot
plt.figure(figsize=(10, 6))
plt.boxplot(df2['Strut Cohesion Intra Plays'])

# Get the statistical values
data = df2['Strut Cohesion Intra Plays']
min_val = np.min(data)
max_val = np.max(data)
mean_val = np.mean(data)
q1 = np.percentile(data, 25)
median_val = np.percentile(data, 50)
q3 = np.percentile(data, 75)

# Highlight the statistical values
highlight_color = 'red'
plt.axhline(y=min_val, color='red', linestyle='--', label='Min')
plt.axhline(y=max_val, color='blue', linestyle='--', label='Max')
plt.axhline(y=mean_val, color='green', linestyle='--', label='Mean')
plt.axhline(y=q1, color='orange', linestyle='--', label='Q1')
plt.axhline(y=median_val, color='purple', linestyle='--', label='Median')
plt.axhline(y=q3, color='black', linestyle='--', label='Q3')

# Set the x-axis labels
xtick_labels = ['Strut Cohesion Intra Plays']
plt.xticks(range(1, len(xtick_labels) + 1), xtick_labels)

# Set the y-axis limits
plt.ylim(0, 1)

# Set the plot title and axis labels
plt.title('Strut Cohesion Intra Plays')
plt.xlabel('Metrics')
plt.ylabel('Strut Cohesion Intra Plays')

# Add a legend
plt.legend()

# Display the plot
plt.tight_layout()
plt.show()
